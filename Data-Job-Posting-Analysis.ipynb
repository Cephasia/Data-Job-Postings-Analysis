# %% [markdown]
# # Data-Jobs Analysis

# %% [markdown]
# ## Project Overview
# This project analyzes Data Jobs from different plartforms/source to uncover genuine insights and support data-driven decision making for stakeholders, CEOs, Executives and even employees to come to the awareness of where they are highly needed and what type of companies needs them the most...

# %% [markdown]
# - ### Import Libraries

# %%
import pandas as pd 

import matplotlib.pyplot as plt

import warnings

warnings.filterwarnings(action='always')

# %% [markdown]
# - ### Data Collection
#       Importing the necessary dataset of ` Data Job dataset` from kaggle for deep cleaning, exploration, visualization and for uncovering insights ☺☺☺... Let's dive in!

# %%
# importing dataset from pc after downloads

jobdata = pd.read_csv(r'C:\Users\DELL\Downloads\data-jobs-dataset\clean_jobs.csv')
jobdata
# Out:
#         id                                              title  \
# 0        1                                       Data Analyst
# 1        2                                       Data Analyst
# 2        3                                       Data Analyst
# 3        4                                       Data Analyst
# 4        5                                    Data Analyst II
# ...    ...                                                ...
# 1043  2521                 Senior GIS/Data Management Analyst
# 1044  2531  Data Science Senior Associate - Card Data & An...
# 1045  2532  Vice President Data Scientist Marketing Analyt...
# 1046  2533           Lead Data Scientist - Finance Technology
# 1047  2534                     Applied AI/ML - Vice President
#
#                       company             location  \
# 0                        Meta         New York, NY
# 1                        Meta    San Francisco, CA
# 2                        Meta      Los Angeles, CA
# ...

# %% [markdown]
# - ### Data Cleaning
#   *The process of cleaning unstructured or an unorganized dataset to be make perfect before exploration to uncover real and actionable insights*
#
#       Dataset-quick-cleaning: It will be a quick one and it won't take time cause the data is not self-generated (web-scraping) but downloaded from kaggle after web-scraped but still unclean, said by the owner - truthy!

# %%
# getting to know the total rows and columns present in the dataset

jobdata.shape
# Out:
# (1048, 10)

# %%
# checking for the sum of blanks within each columns

jobdata.isna().sum()
# Out:
# id                    0
# title                 0
# company               2
# location             15
# link                  0
# source               89
# date_posted          23
# work_type          1048
# employment_type    1048
# description           4
# dtype: int64

# %%
# checking for the sum of unique values in each columns
jobdata.nunique()
# Out:
# id                 1048
# title               523
# company             632
# location            358
# link               1048
# source                3
# date_posted          36
# work_type             0
# employment_type       0
# description         933
# dtype: int64

# %%
# dataset full information - information about data

jobdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048 entries, 0 to 1047
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1048 non-null   int64
#  1   title            1048 non-null   object
#  2   company          1046 non-null   object
#  3   location         1033 non-null   object
#  4   link             1048 non-null   object
#  5   source           959 non-null    object
#  6   date_posted      1025 non-null   object
#  7   work_type        0 non-null      float64
#  8   employment_type  0 non-null      float64
#  9   description      1044 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 82.0+ KB

# %%
# dropping all unnecessary duplicates in the data
jobdata.drop_duplicates()
# Out:
#         id                                              title  \
# 0        1                                       Data Analyst
# 1        2                                       Data Analyst
# 2        3                                       Data Analyst
# 3        4                                       Data Analyst
# 4        5                                    Data Analyst II
# ...    ...                                                ...
# 1043  2521                 Senior GIS/Data Management Analyst
# 1044  2531  Data Science Senior Associate - Card Data & An...
# 1045  2532  Vice President Data Scientist Marketing Analyt...
# 1046  2533           Lead Data Scientist - Finance Technology
# 1047  2534                     Applied AI/ML - Vice President
#
#                       company             location  \
# 0                        Meta         New York, NY
# 1                        Meta    San Francisco, CA
# 2                        Meta      Los Angeles, CA
# ...

# %%
# dragging out useless or unuseful columns in the dataset

jobdata.drop(columns=['work_type','employment_type'], inplace=True)

# %%
# adjusting each column name to make it look presentable, also in the prcess of cleaning
jobdata.rename(columns={'id':'ID', 'title':'JobTitle','company':'Company', 'location':'job_location', 'link':'link_address', 'source':'Source', 'description':'job_description'}, inplace=True)
jobdata
# Out:
#         ID                                           JobTitle  \
# 0        1                                       Data Analyst
# 1        2                                       Data Analyst
# 2        3                                       Data Analyst
# 3        4                                       Data Analyst
# 4        5                                    Data Analyst II
# ...    ...                                                ...
# 1043  2521                 Senior GIS/Data Management Analyst
# 1044  2531  Data Science Senior Associate - Card Data & An...
# 1045  2532  Vice President Data Scientist Marketing Analyt...
# 1046  2533           Lead Data Scientist - Finance Technology
# 1047  2534                     Applied AI/ML - Vice President
#
#                       Company         job_location  \
# 0                        Meta         New York, NY
# 1                        Meta    San Francisco, CA
# 2                        Meta      Los Angeles, CA
# ...

# %%
jobdata[jobdata['Company'].isna()]
# Out:
#         ID                                           JobTitle Company  \
# 947   2344                              Business Analyst (BA)     NaN
# 1001  2441  Healthcare Data Engineer (Remote - Virtual Dem...     NaN
#
#      job_location                                       link_address  Source  \
# 947    Remote, US  https://www.indeed.com/viewjob?jk=1247796689ad...     NaN
# 1001   Remote, US  https://www.indeed.com/viewjob?jk=86f58c4e9351...  indeed
#
#      date_posted                                    job_description
# 947   2025-06-10  MoCaFi is committed to building a financial se...
# 1001  2025-06-06  **If you got into healthcare to make a differe...

# %%
jobdata.fillna('', inplace=True)

# %%
# finally checking if there are still null(NaN) values within each columns after casting them out...

jobdata.isna().sum()
# Out:
# ID                  0
# JobTitle            0
# Company             2
# job_location       15
# link_address        0
# Source             89
# date_posted        23
# job_description     4
# dtype: int64

# %%
# showcasing the 60% cleaned dataset for data jobs

jobdata
# Out:
#         ID                                           JobTitle  \
# 0        1                                       Data Analyst
# 1        2                                       Data Analyst
# 2        3                                       Data Analyst
# 3        4                                       Data Analyst
# 4        5                                    Data Analyst II
# ...    ...                                                ...
# 1043  2521                 Senior GIS/Data Management Analyst
# 1044  2531  Data Science Senior Associate - Card Data & An...
# 1045  2532  Vice President Data Scientist Marketing Analyt...
# 1046  2533           Lead Data Scientist - Finance Technology
# 1047  2534                     Applied AI/ML - Vice President
#
#                       Company         job_location  \
# 0                        Meta         New York, NY
# 1                        Meta    San Francisco, CA
# 2                        Meta      Los Angeles, CA
# ...

# %%
pd.set_option('display.max.rows',40)
pd.set_option('display.max.columns', 20)

# %%
jobdata.groupby('Source').count()
# Out:
#            ID  JobTitle  Company  job_location  link_address  date_posted  \
# Source
#            89        89       89            89            89           89
# LinkedIn  862       862      862           862           862          862
# indeed     25        25       25            25            25           25
# linkedin   72        72       72            72            72           72
#
#           job_description
# Source
#                        89
# LinkedIn              862
# indeed                 25
# linkedin               72

# %% [markdown]
# **Note:**  With this simple solution on series in the jobdata dataset (Source), i found out there are some job source/platform that does not start with capital letter which causes a (`LinkedIn`) source to be two (`linkedin` , `LinkedIn`) different sources.
#
#     You know naww! Let's sort it out, even for some other DataFrame Series...
#
#     ! Done ! Check out 👇

# %%
jobdata['Source'] = jobdata['Source'].str.capitalize()

jobdata.groupby('Source').count()
# Out:
#            ID  JobTitle  Company  job_location  link_address  date_posted  \
# Source
#            89        89       89            89            89           89
# Indeed     25        25       25            25            25           25
# Linkedin  934       934      934           934           934          934
#
#           job_description
# Source
#                        89
# Indeed                 25
# Linkedin              934

# %%
jobdata.groupby('job_description').count()
# Out:
#                                                     ID  JobTitle  Company  \
# job_description
# ##### **Project description**\n\nWe are seeking...   1         1        1
# ...                                                 ..       ...      ...
#
#                                                     job_location  \
# job_description
# ##### **Project description**\n\nWe are seeking...             1
# ...                                                          ...
#
#                                                     link_address  Source  \
# job_description
# ##### **Project description**\n\nWe are seeking...             1       0
# ...                                                          ...     ...
#
#                                                     date_posted
# job_description
# ##### **Project description**\n\nWe are seeking...            1
# ...                                                         ...
#
# [933 rows x 7 columns]

# %%
# removing wrong words or mistakes from the data jobs description

# jobdata['job_description'] =  [description.capitalize().strip('**job description**\n\n\&Overview:ummary:\nas a sr  F ##### ') for description in jobdata['job_description']]

# %%
jobdata['JobTitle'].loc[1020:1043]
# Out:
# 1020         DevOps Engineer - $20K Sign On Bonus - 23285
# 1021         DevOps Engineer - $20K Sign-On Bonus - 23302
# 1022         DevOps Engineer - $20K Sign On Bonus - 23285
# 1023         DevOps Engineer - $20K Sign-On Bonus - 23302
# 1024                                        Data Engineer
# 1025    Analytics Engineer (L5) - New Content Experiences
# 1026                                Analyst Data Engineer
# 1027                                   Data Engineer, ITC
# 1028                                   Data Engineer, ITC
# 1029                                   Data Engineer, ITC
# 1030                           Data/Software Engineer H/F
# 1031                                   Data Engineer(H/F)
# 1032                       Alternance - Data Engineer H/F
# 1033                          Stage - Data Engineer (H/F)
# 1034                          Software Engineer - Android
# 1035                                    Data Engineer F/H
# ...

# %% [markdown]
# - ### Observation
#     🔍 Even without me saying anything, does the look of the above `job descriptions` ✌ look pleasing to you? Although it's not really playing a great role in the analysis solution, sooo for us not to later have problem with it, let's get rid of it now and move on with the key ones that are valuable for the uncovering of the actionable precious insights but i won't get rid of  it yet, don't be scared😎✌....
#
#
# - ### Microsoft Excel
#     🛠️ Let's finish the cleaning process with `Microsoft Excel` to support and upgrade what we've done, don't forget that what we really want is to give key and actionable insights, recommendations, observations for the help/sake of our stakeholders, clients, executives and anybody that needs it. Thanks for following the process, we will be back soon, moving on with `Exploration Data Analysis`.

# %%
jobdata.to_excel(r'C:\Users\DELL\Downloads\data-jobs-dataset\datajobs-dataset.xlsx')

# %% [markdown]
# ### 🚀 Hello!!!
#
#       We're finally back for the Exploratory Data Analysis of the deeply cleaned data-jobs dataset with Microsoft Excel... Let me take you through little of what we've done on the data with Microsoft Excel to call it a clean one ☺ You will love it!
#
# - *No more Job description*
# - *Rows and series are now cleaned*
# - *A table of `1043` rows now contains `975` rows after deep cleaning*
# - *Also contains `7` seven columns*
# - *Now well arranged in order*
# - *Finally available for EDA process* ______________________ Let's move on by calling it in ✌✌✌

# %%
jobdata2 = pd.read_excel(r'C:\Users\DELL\Downloads\data-jobs-dataset\datajobs-cleaned-dataset.xlsx', sheet_name='Data_Job_Sheet')

# %%
print(jobdata.shape)
print(jobdata2.shape)
# Out:
# (1048, 8)
# (975, 7)

# %% [markdown]
# - ### Exploratory Data Analysis

# %%
jobdata2.tail(10)
# Out:
#        ID                                           JobTitle  \
# 965  2513                            Principal Data Engineer
# 966  2514                            Principal Data Engineer
# 967  2515                 Global Technology Strategy Analyst
# 968  2519                             Cyber Security Analyst
# 969  2520                      RCM Business Analyst - Remote
# 970  2521                 Senior GIS/Data Management Analyst
# 971  2531  Data Science Senior Associate - Card Data & An...
# 972  2532  Vice President Data Scientist Marketing Analyt...
# 973  2533           Lead Data Scientist - Finance Technology
# 974  2534                     Applied AI/ML - Vice President
#
#                      Company         job_location  \
# 965          Oracle Database                  NaN
# 966          Oracle Database                  NaN
# 967            JPMorganChase     New York, NY, US
# 968      Chenega Corporation   Washington, DC, US
# ...

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
# choosing suiting style from the matplotlib available style for visualition...
plt.style.use('classic')

# %%
# Just giving another way out!!!😎✌

companies = jobdata2['Company'].value_counts(normalize=False)
TopHiringCompany1 = hope1.head(10)

# %%
# calling out the top ten(10) hiring companies

companies = jobdata2.groupby('Company').agg({'ID':'count'}).sort_values(by='ID', ascending=False)
TopHiringCompany = hope.head(10)

jobdata2['Company'].value_counts()
# Out:
# Company
# Meta                       70
# Netflix                    33
# Amazon                     18
# Google                     16
# Lensa                       9
#                            ..
# Equitable                   1
# Vevo                        1
# AppsFlyer                   1
# Korn Ferry                  1
# Carollo Engineers, Inc.     1
# Name: count, Length: 599, dtype: int64

# %%
# Top ten(10) companies hiring data jobs, showcased with matplotlib bar chart...

TopHiringCompany.plot.bar(ylabel='Job_Count')
# Out:
# <Axes: xlabel='Company', ylabel='Job_Count'>

# %%
# Calling out also the top ten most hiring data job
# What are those jobs these companies that hires the most are hiring.... Let's get to showcase that with a chart!

TopHiringJob = jobdata2['JobTitle'].value_counts()
TopHiringJob
# Out:
# JobTitle
# Data Analyst                                                 152
# Data Scientist                                                75
# Data Engineer                                                 58
# Data Scientist, Product Analytics                             29
# Machine Learning Engineer                                     21
#                                                             ...
# Data Analyst Staff - Jakarta                                   1
# Insight Analyst UK                                             1
# Analista Dados JR                                              1
# Business Intelligence Analyst, Global Research Operations      1
# Applied AI/ML - Vice President                                 1
# Name: count, Length: 478, dtype: int64

# %%
TopHiringJob.head(10).sort_values(ascending=True).plot.barh()
# Out:
# <Axes: ylabel='JobTitle'>

# %%
# Noww let's know the source by which company posted available data jobs role the most.
# and also check the total sum of data jobs role posted for hire in each job app/source....

jobdata2['Source'].isna().sum()
jobdata2['Source'].fillna('Others', inplace=True)

# %%
TopJobPostingSource = jobdata2['Source'].value_counts()
TopJobPostingSource
# Out:
# Source
# Linkedin    862
# Others       88
# Indeed       25
# Name: count, dtype: int64

# %%
TopJobPostingSource.plot.pie(ylabel='Job Count')
# Out:
# <Axes: ylabel='Job Count'>

# %%
# Finally let's get everything done by moving into the areas jobs data are needed the most

TopAreas = jobdata2['job_location'].value_counts()
TopAreas
# Out:
# job_location
# United States                               73
# New York, NY                                65
# San Francisco, CA                           48
# Bengaluru, Karnataka, India                 40
# Remote, US                                  23
#                                             ..
# County Dublin, Ireland                       1
# Bogota, D.C., Capital District, Colombia     1
# Kent, England, United Kingdom                1
# Christchurch, Canterbury, New Zealand        1
# Jersey City, NJ, US                          1
# Name: count, Length: 325, dtype: int64

# %%
TopAreas.head().plot.line(figsize=(15,5), linewidth=2, marker='p', markersize=13, color='black')
# Out:
# <Axes: xlabel='job_location'>

# %% [markdown]
# - ### Derived Insights

# %% [markdown]
# #### 1. **Top 10 hiring Company** | *company that hires data-jobs the most accross all platform/app*
#
# `Meta Company Limited` requested for data jobs the most with the total of `70 job postings` fololowed by `Netflix` with `33 job postings` and `Amazon` with `18 job postings` accross all job-app...
#
# #### 2. **Top 10 job postings** | *Most requested/posted data-job role for hire*
#
# `Data Analyst` role came out as the most posted job available for hire followed by `Data Scientist` accross all job-app...
#
# #### 3. **Job posting top platform/app** | *platforms in which data jobs are highly posted for hire*
#
# Yeah, it's `LinkedIn`, available data jobs for hire are posted or available on `LinkedIn`. Also know that `Others` includes multiple job-app like; `Jobberman`, `MyJobMag`, and any other job-app actively available in the world...
#
# #### 4. **Areas demanding for data-jobs** | *Locations where data jobs are requested from for hire*
#
# With the analysis, data jobs are needed the most in `United States` because it's the location that generates the highest job postings accross all job-app...

# %% [markdown]
# #     THANKS FOR TAKING YOUR TIME..........................................................THE END!!!
